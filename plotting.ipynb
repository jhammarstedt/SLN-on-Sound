# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# results 1
sym10snl = pd.read_json('results/cifar10symmetric/training_log_base.json',)
sym10 = pd.read_json('results/cifar10_symmetric_noSLN/training_log.json',)
asym10snl = pd.read_json('results/cifar10_asymmetric/training_log.json',)
asym10 = pd.read_json('results/cifar10_asymmetric_noSLN/training_log.json',)
sym100snl = pd.read_json('results/cifar100_symmetric/training_log.json',)
asym100snl = pd.read_json('results/cifar100_asymmetric/training_log.json',)
sym100 = pd.read_json('results/cifar100_symmetric_noSLN/training_log.json',)
# asym100 = pd.read_json('results/cifar100_asymmetric_noSLN/training_log.json',)
fsd_sym_snl = pd.read_json('results/fsd_symmetric/training_log.json',)
fsd_sym = pd.read_json('results/fsd_symmetric_noSLN_14/training_log.json',)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/nt/kxvzdqxx14x0llcz9jr02x240000gn/T/ipykernel_3500/3325923738.py in <module>
#       1 # results 1
# ----> 2 sym10snl = pd.read_json('results/cifar10symmetric/training_log_base.json',)
#       3 sym10 = pd.read_json('results/cifar10_symmetric_noSLN/training_log.json',)
#       4 asym10snl = pd.read_json('results/cifar10_asymmetric/training_log.json',)
#       5 asym10 = pd.read_json('results/cifar10_asymmetric_noSLN/training_log.json',)
#
# ~/miniforge3/envs/dl-pytorch/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     205                 else:
#     206                     kwargs[new_arg_name] = new_arg_value
# --> 207             return func(*args, **kwargs)
#     208
#     209         return cast(F, wrapper)
#
# ...

# %%
#results2
sym10snl = pd.read_json('results2/cifar10sym.json',)
sym10 = pd.read_json('results2/cifar10sym_noSLN.json',)
asym10snl = pd.read_json('results2/cifar10asym.json',)
asym10 = pd.read_json('results2/cifar10asym_noSLN.json',)
sym100snl = pd.read_json('results2/cifar100sym.json',)
asym100snl = pd.read_json('results2/cifar100asym.json',)
sym100 = pd.read_json('results2/cifar100sym_noSLN.json',)
asym100 = pd.read_json('results2/cifar100asym_noSLN.json',)

sym100_LC = pd.read_json('results2/cifar100_sym_noSLN_LC.json',)
asym100_LC = pd.read_json('results2/cifar100_asym_noSLN_LC.json',)

fsd_sym = pd.read_json('sound_res/No_SLN/training_log.json',)
fsd_sym_snl = pd.read_json('sound_res/SLN/training_log.json',)

# %%
def plot(data, labels, title='CIFAR-10 test accuracy', ylabel='Accuracy'):
    for i in range(len(data)):
        plt.plot(data[i], label=labels[i])
    plt.title(title)
    plt.grid(True)
    plt.legend()
    plt.xlabel('Epoch')
    plt.ylabel(ylabel)
    plt.savefig(f'./plots/new_plots/{title}.png')
    plt.show()

# %%
# plt.plot(sym10snl.test_acc)
# plt.plot(sym10.test_acc)
plot([sym10snl.test_acc, sym10.test_acc, asym10snl.test_acc, asym10.test_acc], 
     ['Symmetric with SLN', 'Symetric without SLN', 'Asymmetric with SLN', 'Asymetric without SLN'], 
     title='CIFAR-10 test accuracy'
    )

# %%
plot([sym10snl.train_acc, sym10.train_acc, asym10snl.train_acc, asym10.train_acc], 
     ['Symmetric with SLN', 'Symetric without SLN', 'Asymmetric with SLN', 'Asymetric without SLN'], 
     title='CIFAR-10 train accuracy'
    )

# %%
plot([sym10snl.train_loss, sym10.train_loss, asym10snl.train_loss, asym10.train_loss], 
     ['Symmetric with SLN', 'Symetric without SLN', 'Asymmetric with SLN', 'Asymetric without SLN'],
     title='CIFAR-10 train loss',
     ylabel='CE loss'
    )

# %%
plot([sym10snl.test_loss, sym10.test_loss, asym10snl.test_loss, asym10.test_loss, ], 
     ['Symmetric with SLN', 'Symmetric without SLN', 'Asymmetric with SLN', 'Asymmetric without SLN',], 
     title='CIFAR-10 test loss',
     ylabel='CE loss'
    )

# %%
plot([sym100snl.test_acc, asym100snl.test_acc, sym100.test_acc, asym100.test_acc], 
     ['Symmetric with SLN', 'Asymmetric with SLN', 'Symmetric without SLN', 'Asymetric without SLN'], 
     title='CIFAR-100 test accuracy'
    )

# %%
plot([sym100snl.train_acc,  asym100snl.train_acc, sym100.train_acc,  asym100.train_acc, sym100_LC.train_acc, asym100_LC.train_acc,], 
     ['Symmetric with SLN', 'Asymmetric with SLN','Symetric without SLN',  'Asymetric without SLN', 'Symetric without SLN, with LC',  'Asymetric without SLN, with LC',], 
     title='CIFAR-100 train accuracy'
    )

# %%
sym10snl.test_acc.max(), sym10.test_acc.max(), asym10snl.test_acc.max(), asym10.test_acc.max()
# Out:
# (0.8605, 0.7872, 0.8711000000000001, 0.8343)

# %%
sym100snl.test_acc.max(), asym100snl.test_acc.max(), sym100.test_acc.max(), asym100.test_acc.max()
# Out:
# (0.5745, 0.6168, 0.5208, 0.48650000000000004)

# %%
plot([fsd_sym_snl.test_acc, fsd_sym.test_acc], 
     ['Symmetric with SLN', 'Symmetric without SLN'], 
     title='FSD50k test accuracy'
    )

# %%
plot([fsd_sym_snl.train_acc, fsd_sym.train_acc], 
     ['Symmetric with SLN', 'Symmetric without SLN'], 
     title='FSD50k train accuracy'
    )

# %%
plot([fsd_sym_snl.train_loss, fsd_sym.train_loss], 
     ['Symmetric with SLN', 'Symmetric without SLN'], 
     title='FSD50k train loss',
     ylabel='CE loss'
    )
